# %% [markdown]
# # Pima Indians Diabetes

# %% [markdown]
# ## 0. Prepare

# %% [markdown]
# Import modules to work with Azure Machine Learning

# %%
from azureml.core import Workspace, Dataset

# %% [markdown]
# Connect to Azure ML workspace

# %%
subscription_id = '<your_subscription_id>' # WARN: cahnge on your subscription_id
resource_group = 'ai-in-cloud-workshop-rg'
workspace_name = 'ai-in-cloud-workspace'

workspace = Workspace(subscription_id, resource_group, workspace_name)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# ## 1. Upload dataset

# %%
dataset = Dataset.get_by_name(workspace, name='Pima Indians Diabetes Database')
dataset

# %% [markdown]
# Convert to pandas data frame

# %%
data = dataset.to_pandas_dataframe()
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %% [markdown]
# Dataset __descriptive statistics__

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Plot a __correlation matrix__

# %%
import seaborn as sns

corr = data.corr()

ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# Plot boxplots

# %%
data.boxplot(column=['BMI', 'Age', 'Glucose'], by='Outcome', layout=(1, 3), figsize=(16, 9))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb328976438>,
# ...
#       dtype=object)
